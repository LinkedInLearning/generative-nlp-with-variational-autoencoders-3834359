# %%
import random
import numpy as np
from tensorflow.keras.datasets import imdb
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Dense, LSTM, RepeatVector, TimeDistributed, Embedding, Dropout, Bidirectional, GRU
from tensorflow.keras.optimizers import Adam
from gensim.models import Word2Vec
from tensorflow.keras.callbacks import EarlyStopping
from keras.losses import SparseCategoricalCrossentropy
from tensorflow.keras.utils import to_categorical

# Parameters for the model
embedding_dim = 300
latent_dim = 256

# Parameters
vocab_size = 10000
max_length = 150
epochs = 200
batch_size = 256
learning_rate = 0.01

# Load IMDB dataset
(x_train, _), (x_test, _) = imdb.load_data(num_words=vocab_size)
word_index = imdb.get_word_index()

# Create a reverse word index
reverse_word_index = {value + 3: key for key, value in word_index.items()}
reverse_word_index[0] = '<PAD>'
reverse_word_index[1] = '<START>'
reverse_word_index[2] = '<UNK>'
reverse_word_index[3] = '<UNUSED>'

# Convert sequences back to text
train_texts = [[reverse_word_index.get(i, '<UNK>') for i in sequence] for sequence in x_train]
test_texts = [[reverse_word_index.get(i, '<UNK>') for i in sequence] for sequence in x_test]
all_texts = train_texts + test_texts

# %%
# Train a Word2Vec model
word2vec_model = Word2Vec(sentences=all_texts, vector_size=embedding_dim, window=5, min_count=1, workers=4, epochs=20)

# Convert the word2vec model to a dictionary
# Create an embedding matrix where each row index corresponds to a word index
embedding_matrix = np.zeros((vocab_size, embedding_dim))
for word, i in word_index.items():
    if i < vocab_size:
        try:
            embedding_vector = word2vec_model.wv[word]
            embedding_matrix[i] = embedding_vector
        except KeyError:
            # Words not found in the embedding index will be all zeros
            pass

# %%
def sequence_to_text(sequence):
    return ' '.join([reverse_word_index.get(i - 3, '?') for i in sequence])

def add_noise_to_text(sequence, noise_factor=0.1):
    noisy_sequence = []
    for i in sequence:
        if random.random() < noise_factor:
            # Randomly replace a word with another word
            noisy_sequence.append(random.randint(1, vocab_size - 1))
        else:
            noisy_sequence.append(i)
    return noisy_sequence

# Add noise to the data
noisy_x_train = [add_noise_to_text(seq) for seq in x_train]
noisy_x_test = [add_noise_to_text(seq) for seq in x_test]

# Convert to padded sequences
noisy_x_train_padded = pad_sequences(noisy_x_train, maxlen=max_length, padding='post')
noisy_x_test_padded = pad_sequences(noisy_x_test, maxlen=max_length, padding='post')

# Example of noisy text
print("Original:", sequence_to_text(x_train[0]))
print("Noisy:", sequence_to_text(noisy_x_train[0]))
# Out:
# Original: ? in with i like horrible business chinese charm would killer waited which explosion <START> going at fun <UNK> film make like lame character has novel ? a all final sense <UNK> real <START> find character nothing ? second perhaps they <START> find valuable cover this city an br overall <START> horror has i <UNUSED> should shop was in with <START> delightful 00 despite <START> with their people is i like horrible an well it br garbage <START> with this genre this is i taken that ? <UNK> she sex is and house and after <UNK> <START> product bud i final which returned be <START> does is i an annoying <UNK> film where if at man it's film sent be <UNUSED> with is comedy you than some <UNK> in perfect i get ? and <START> think plot windows it fun <START> ? the lou <UNK> sequence at their like horrible wanted on getting night just the <START> ? rich br any other <START> couple it someone then he decade more on why <UNUSED> can't ajay that <START> family with for still wanted on final <UNK> such his lindsay that if at you interesting how film any <START> family would i an g other is i once <UNK> i boot seen could he it i pitiful was every he
# Noisy: ? in tribe i like horrible business chinese charm would seasons waited which lou <START> going at fun <UNK> film make like lame character has novel ? a all final sense <UNK> real <START> turkey character nothing literature second perhaps they rogue find valuable cover this city an br overall <START> horror has i <UNUSED> should shop was in with priest delightful 00 despite <START> with their people is i like twelve an well three br garbage <START> with this genre this is i taken that ? <UNK> she sex is and house and believable <UNK> <START> product bud i final which returned be <START> does is i an annoying <UNK> film where if at man it's film sent be confess with is comedy you than some matthew in perfect i get ? and <START> think plot windows it fun <START> ? the lou <UNK> sequence at their like horrible wanted on getting astaire just the <START> together rich br any other <START> couple it someone thank he decade more on why <UNUSED> can't ajay that <START> family with for still wanted fellow final <UNK> such his lindsay that if at you interesting how film any hinted family would i an g other is i once <UNK> i boot seen could honest it i pitiful was every he

# %%
# Encoder
input_text = Input(shape=(max_length,))
encoder_embedding = Embedding(vocab_size, embedding_dim, weights=[embedding_matrix], trainable=False)(input_text)
encoder_output = Bidirectional(LSTM(2*latent_dim, return_sequences=False))(encoder_embedding)
encoder_output = Dropout(0.15)(encoder_output)
encoder_output = Dense(latent_dim, activation='relu')(encoder_output)

# Decoder
decoder_input_seq = Input(shape=(max_length - 1,))
decoder_embedding = Embedding(vocab_size, embedding_dim, weights=[embedding_matrix], trainable=False)(decoder_input_seq)
decoder_input = RepeatVector(max_length)(encoder_output)
decoder_lstm = LSTM(latent_dim, return_sequences=True)(decoder_input)
decoder_lstm = Dropout(0.15)(decoder_lstm)
decoder_lstm = LSTM(2*latent_dim, return_sequences=True)(decoder_lstm)
decoder_output = TimeDistributed(Dense(vocab_size, activation='softmax'))(decoder_lstm)


# Compile and train with MSE loss
autoencoder = Model([input_text, decoder_input_seq], decoder_output)
autoencoder.compile(optimizer=Adam(learning_rate=learning_rate, clipnorm=1.0), loss='sparse_categorical_crossentropy')

# # First, pad the sequences to max_length
x_train_padded = pad_sequences(x_train, maxlen=max_length, padding='post')
x_test_padded = pad_sequences(x_test, maxlen=max_length, padding='post')

# y_train and y_test are simply the padded original sequences
y_train = x_train_padded
y_test = x_test_padded

# Prepare decoder_input_data by shifting the sequences by one position
decoder_input_train = np.zeros((x_train_padded.shape[0], max_length - 1), dtype=int)
decoder_input_test = np.zeros((x_test_padded.shape[0], max_length - 1), dtype=int)

for i in range(len(x_train_padded)):
    decoder_input_train[i] = x_train_padded[i, 1:]  # Drop the first word

for i in range(len(x_test_padded)):
    decoder_input_test[i] = x_test_padded[i, 1:]  # Drop the first word

# %%
autoencoder.summary()
# Out:
# Model: "model_2"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_13 (InputLayer)       [(None, 150)]                0         []
#
#  embedding_12 (Embedding)    (None, 150, 300)             3000000   ['input_13[0][0]']
#
#  bidirectional_8 (Bidirecti  (None, 1024)                 3330048   ['embedding_12[0][0]']
#  onal)
#
#  dropout_9 (Dropout)         (None, 1024)                 0         ['bidirectional_8[0][0]']
#
#  dense_7 (Dense)             (None, 256)                  262400    ['dropout_9[0][0]']
#
#  repeat_vector_5 (RepeatVec  (None, 150, 256)             0         ['dense_7[0][0]']
#  tor)
#
#  lstm_14 (LSTM)              (None, 150, 256)             525312    ['repeat_vector_5[0][0]']
#
#  dropout_10 (Dropout)        (None, 150, 256)             0         ['lstm_14[0][0]']
#
#  lstm_15 (LSTM)              (None, 150, 512)             1574912   ['dropout_10[0][0]']
#
#  input_14 (InputLayer)       [(None, 149)]                0         []
#
#  time_distributed_2 (TimeDi  (None, 150, 10000)           5130000   ['lstm_15[0][0]']
#  stributed)
#
# ==================================================================================================
# Total params: 13822672 (52.73 MB)
# Trainable params: 10822672 (41.29 MB)
# Non-trainable params: 3000000 (11.44 MB)
# __________________________________________________________________________________________________

# %%
from tensorflow.keras.callbacks import LearningRateScheduler
import tensorflow.keras.backend as K

def custom_lr_scheduler(epoch, lr):
    # Decrease learning rate by 0.1 factor every 5 epochs
    if epoch % 5 == 0 and epoch != 0:
        lr = lr * 0.1
    return lr

# Define the callback
lr_scheduler = LearningRateScheduler(custom_lr_scheduler)
early_stopping = EarlyStopping(monitor='loss', patience=5, restore_best_weights=True)

# Train the model
autoencoder.fit([noisy_x_train_padded, decoder_input_train], np.expand_dims(y_train, -1),
          epochs=epochs,
          batch_size=batch_size,
          validation_data=([noisy_x_test_padded, decoder_input_test], np.expand_dims(y_test, -1)),
          callbacks=[early_stopping, lr_scheduler])
# Out:
# Epoch 1/200
# 98/98 [==============================] - 30s 244ms/step - loss: 6.4819 - val_loss: 6.3421 - lr: 0.0100
# Epoch 2/200
# 98/98 [==============================] - 23s 231ms/step - loss: 6.3831 - val_loss: 6.3650 - lr: 0.0100
# Epoch 3/200
# 98/98 [==============================] - 23s 231ms/step - loss: 6.3940 - val_loss: 6.3475 - lr: 0.0100
# Epoch 4/200
# 98/98 [==============================] - 23s 230ms/step - loss: 6.3941 - val_loss: 6.3679 - lr: 0.0100
# Epoch 5/200
# 98/98 [==============================] - 23s 231ms/step - loss: 6.3999 - val_loss: 6.3685 - lr: 0.0100
# Epoch 6/200
# 98/98 [==============================] - 23s 231ms/step - loss: 6.3407 - val_loss: 6.2908 - lr: 1.0000e-03
# Epoch 7/200
# 98/98 [==============================] - 23s 231ms/step - loss: 6.3340 - val_loss: 6.2904 - lr: 1.0000e-03
# Epoch 8/200
# 98/98 [==============================] - 23s 231ms/step - loss: 6.3338 - val_loss: 6.2903 - lr: 1.0000e-03
# Epoch 9/200
# 98/98 [==============================] - 23s 231ms/step - loss: 6.3335 - val_loss: 6.2915 - lr: 1.0000e-03
# Epoch 10/200
# 98/98 [==============================] - 23s 231ms/step - loss: 6.3334 - val_loss: 6.2891 - lr: 1.0000e-03
# Epoch 11/200
# 98/98 [==============================] - 23s 231ms/step - loss: 6.3275 - val_loss: 6.2832 - lr: 1.0000e-04
# Epoch 12/200
# 98/98 [==============================] - 23s 231ms/step - loss: 6.3259 - val_loss: 6.2828 - lr: 1.0000e-04
# Epoch 13/200
# 98/98 [==============================] - 23s 231ms/step - loss: 6.3258 - val_loss: 6.2832 - lr: 1.0000e-04
# Epoch 14/200
# 98/98 [==============================] - 23s 232ms/step - loss: 6.3258 - val_loss: 6.2827 - lr: 1.0000e-04
# Epoch 15/200
# 98/98 [==============================] - 23s 231ms/step - loss: 6.3258 - val_loss: 6.2828 - lr: 1.0000e-04
# Epoch 16/200
# 98/98 [==============================] - 23s 232ms/step - loss: 6.3250 - val_loss: 6.2827 - lr: 1.0000e-05
# Epoch 17/200
# 98/98 [==============================] - 23s 232ms/step - loss: 6.3248 - val_loss: 6.2826 - lr: 1.0000e-05
# Epoch 18/200
# 98/98 [==============================] - 23s 231ms/step - loss: 6.3248 - val_loss: 6.2826 - lr: 1.0000e-05
# Epoch 19/200
# 98/98 [==============================] - 23s 231ms/step - loss: 6.3248 - val_loss: 6.2826 - lr: 1.0000e-05
# Epoch 20/200
# 98/98 [==============================] - 23s 232ms/step - loss: 6.3248 - val_loss: 6.2826 - lr: 1.0000e-05
# Epoch 21/200
# 98/98 [==============================] - 23s 231ms/step - loss: 6.3246 - val_loss: 6.2826 - lr: 1.0000e-06
# Epoch 22/200
# 98/98 [==============================] - 23s 231ms/step - loss: 6.3246 - val_loss: 6.2826 - lr: 1.0000e-06
# Epoch 23/200
# 98/98 [==============================] - 23s 232ms/step - loss: 6.3246 - val_loss: 6.2826 - lr: 1.0000e-06
# Epoch 24/200
# 98/98 [==============================] - 23s 231ms/step - loss: 6.3246 - val_loss: 6.2826 - lr: 1.0000e-06
# Epoch 25/200
# 98/98 [==============================] - 23s 232ms/step - loss: 6.3246 - val_loss: 6.2826 - lr: 1.0000e-06
# Epoch 26/200
# 98/98 [==============================] - 23s 232ms/step - loss: 6.3246 - val_loss: 6.2826 - lr: 1.0000e-07
# Epoch 27/200
# 98/98 [==============================] - 23s 232ms/step - loss: 6.3246 - val_loss: 6.2826 - lr: 1.0000e-07
# Epoch 28/200
# 98/98 [==============================] - 23s 232ms/step - loss: 6.3246 - val_loss: 6.2826 - lr: 1.0000e-07
# Epoch 29/200
# 98/98 [==============================] - 23s 231ms/step - loss: 6.3246 - val_loss: 6.2826 - lr: 1.0000e-07
# Epoch 30/200
# 98/98 [==============================] - 23s 232ms/step - loss: 6.3246 - val_loss: 6.2826 - lr: 1.0000e-07
# Epoch 31/200
# 98/98 [==============================] - 23s 232ms/step - loss: 6.3246 - val_loss: 6.2826 - lr: 1.0000e-08
# Epoch 32/200
# 98/98 [==============================] - 23s 232ms/step - loss: 6.3246 - val_loss: 6.2826 - lr: 1.0000e-08

# %%
def sample(preds, temperature=1.0):
    # Convert to array and prevent numerical issues with very small numbers
    preds = np.asarray(preds).astype('float64')
    preds = np.log(preds + 1e-7) / temperature  # Adjust by temperature
    exp_preds = np.exp(preds)
    preds = exp_preds / np.sum(exp_preds)  # Softmax
    probas = np.random.multinomial(1, preds, 1)  # Sample from the softmax distribution
    return np.argmax(probas)

# %%
import tensorflow as tf
# Prepare the decoder input for prediction
decoder_input_test = np.zeros((noisy_x_test_padded.shape[0], max_length - 1), dtype=int)
for i in range(len(x_test_padded)):
    decoder_input_test[i] = x_test_padded[i, 1:]  # Drop the first word

# Predicting denoised text
denoised_texts = autoencoder.predict([noisy_x_test_padded[:10], decoder_input_test[:10]])

# Function to convert sequences back to text
def decode_denoised_sequence(sequence):
    indices = tf.math.argmax(sequence, axis=1).numpy()
    return ' '.join([reverse_word_index.get(word, '?') for word in indices])

def decode_sequence_with_sampling(prob_distributions, temperature=1.0):
    return ' '.join([reverse_word_index.get(sample(probs, temperature), '?') for probs in prob_distributions])

# Decoding the denoised sequences
for i in range(10):
    print("Original:", sequence_to_text(x_test[i]))
    print("Noisy:", sequence_to_text(noisy_x_test_padded[i]))
    print("Generated:", decode_sequence_with_sampling(denoised_texts[i], temperature=1))
    print("\n")
# Out:
# 1/1 [==============================] - 0s 33ms/step
# Original: ? murder both in have <UNUSED> easily of of ? ? <UNK> <START> boring the <START> again marries understand dead <START> over a odd odd odd of of br how where first lead spiral make you cross in have movie not convict are role dark and where in true director and old just <UNK> not last i lot ? an he film spiral based both in <UNUSED> easily
# Noisy: ? suggest both in have <UNUSED> easily of of ? ? <UNK> <START> boring the <START> again marries understand dead <START> clue a odd odd odd of of br how where first lead spiral make you cross in have movie not convict are role dark revolution where in true director and old just <UNK> wounded last i lot dance an he film spiral based both in <UNUSED> easily ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ?
# Denoised: <START> <UNK> funny anything there written where a second fully suspenseful i <PAD> a that with crafted by first <PAD> again <PAD> are john <PAD> understand supporting pulled <PAD> shows this of it scenes <PAD> features <PAD> weird you <UNK> and a funny budget either will i wound star our for the tone degree flaws the testament <UNK> you redeeming but the these good everything <PAD> in movies the my house if <PAD> watching be just not were the from i <PAD> <UNK> knew <PAD> sucks <UNK> <PAD> can movies though give <UNK> <PAD> also footage the cinema i i all a the <PAD> the <PAD> cook an <PAD> is tired black movie <UNK> like lines to really <PAD> three see noticed my the ends of br in each on have <PAD> world <PAD> about <PAD> has is <UNK> be and <PAD> in a <UNK> look of to stars little
#
#
# Original: ? in with cardboard <UNUSED> part the greg other is alice movie terrific <UNK> watch directing <START> many a good score <UNK> films the <START> scene however set movie <START> find looking to rambling ? <START> henchman greater watch industry for <START> with slave and <UNUSED> awesome movie's of of <START> movies present all imagine ? was wait public <UNK> humorous ? or good isn't it novel husband's eyes in members <START> early <UNK> australian the not also characters better <START> yard husband's symbolism early a hanks end <UNK> has br any if which funny in with old a <START> horrible last one henchman greater or perfect have the so sticks movies for up watched is an mess <UNK> pants it or released lead destroyed know <UNUSED> some three this <START> deputy world your werewolf husband's soft lead lights about <UNUSED> wonderful going <START> ? stereotype looking satisfying <START> share the <START> would good can to used in as a <UNUSED> casting lewis the knocked wait ? <UNK> exotic his sexuality ? more <START> imagine <UNK> create four and <START> sleep playing whole of of br criminals novel husband's in a have the not films characters it director's was sherlock emotion decided fight in with a awesome for or greed <UNK> or worst and ? <UNUSED> took forced cole they <START> directed it's film us and only all actions with out feel no man impressive in a shows <START> very of of throughout or good subject and makes to truly unrelated film between you and weak is did <START> sin
# Noisy: sticks movies for up watched is an mess <UNK> waves it or released lead tad know <UNUSED> some three this <START> deputy world your werewolf husband's soft lead lights about <UNUSED> wonderful going <START> mortal stereotype nonexistent satisfying <START> share the <START> would good passenger to used in as a <UNUSED> rocket lewis the knocked wait ? <UNK> exotic recalls sexuality ? more <START> imagine <UNK> create four and hostage sleep playing whole of propaganda br criminals villainous husband's in a have the not films characters it director's was sherlock emotion decided fight in with a awesome for or greed robot or worst and ? <UNUSED> took forced cole tones <START> directed it's film us documentaries only all actions with out our no man impressive in a shows <START> very of of throughout or good subject and action to truly unrelated affair between you and weak is did <START> sin
# Denoised: <START> family done these years without soldiers <PAD> quite the stand very at the <PAD> cinema and with the for this disappointed the <PAD> and are like been de sense s to <PAD> <PAD> seem get about <PAD> us i is but the the the use and it were nevertheless the in the state to <PAD> a between film the simply her best we for with any the batman in a and hardcore <PAD> and in odd which film coming <PAD> different and with reminded or in <UNK> final character film <PAD> if that to for that else this of wrong to what to though out of <PAD> not <PAD> sound is over <UNK> choreography favorite scenes part humour <PAD> owner just without the moves and done and the wonder role can but br the <PAD> lee film <UNK> and <PAD> <PAD> stuff it powell i stephen of got <PAD>
#
#
# Original: ? films richard kicked store ? ? <START> people childhood smith the have during viggo the <START> works mtv richard even are subjected role call ? <UNK> this is particularly role invisible this <UNUSED> world your ? i there dream to ? were <START> went for not ? wouldn't and with think ? ? return lord and all suffering cousins to with music what are build are make ? reporter one ? mocking ? <UNK> ? then have sake be <UNUSED> very in joey lord and <START> kids the description misses try used <START> ? filmmakers even are him to 1988 to ? be <UNUSED> very what appearance white richard the he reputation i to most ? of of <START> pay ? the <START> limited unconvincing round ? and sequences and born best have the not into rolling ? i <UNUSED> laugh pay behavior ? stop this ? from <START> ? by 4 <UNUSED> thriller <UNUSED> liberties the war without see his woman to role he the characters for end is a good laugh parents conceived there be decade international by see common <START> hum track were wanted by she because themes makes <START> movie's ? through opinion described <UNK> woman is want ? city <UNK> parents ? the <START> with names that david hoping follow the <START> trusted their either yes limits large was ? <UNK> ? to husband and father ? <START> claims ? the <START> skills of of having hate a looking to <UNUSED> victoria's <START> ? ? best <START> hawke on amanda was story presence <UNK> you mr <UNUSED> during unanswered and only if at see bad and shirley par at changed and ? ? that <UNUSED> thriller <START> spaces on ? italian to in usually miss is liked you than named and its an films profile des actually magic females these ? that not going a fare this <UNUSED> ? title ? script to <START> timmy by trying who caine am his change <UNUSED> ? what ? stunts then <UNUSED> choices who roles by pc then <START> ? changed it in a when masterpieces <UNK> stooges <UNUSED> looks thriller mud ? stunts then <UNUSED> ? of of bounty was in ? believe before thriller by differently message then <START> ? relatively great was <UNUSED> ? the ? clichés ? <START> incompetent grey writers and turns great <START> fully and <START> ? this ? margaret players <START> step and waited seems <START> ? divorced globe <START> incompetent <UNK> don't screen movie <UNUSED> vargas describing ? hawke be thin <UNUSED> yes millions ? alcoholic mom the <START> advise ? despite <START> secretly what <START> real dates ? ending there ? ? that father are portray not melancholy <UNK> ? story heaven was pixar ? <START> holes the having would laughter one <UNUSED> hopkins profile like actors are a signed a mean can fact living of of members <START> very dialog what in restrained plot with i him <UNK> members <START> horror it is i him one <UNUSED> limited ? be <START> connections the it ? sematary factory wife is she his named and only in this <UNUSED> ? her back apparently ? between from between but you really ? divine to nice what are him ? for hear ? not clever the soundtrack <START> with ahead this <UNUSED> ? hate the ruin ? ? make his <START> marks ironically oscars excitement from keeping to <START> screams from them non the them fails it location most amongst cast <UNK> a honeymoon one ? or <UNUSED> emotion with no <UNUSED> meaning have to most syndrome made for most within a when apart
# Noisy: heaven was pixar ? <START> holes the having would grave one <UNUSED> hopkins profile like actors are a signed a mean can fact living of of members <START> very dialog what in restrained plot with i him <UNK> members <START> horror it is i him star jennifer thrillers ? be <START> connections the it ? sematary factory wife is she his named and only in this <UNUSED> ? her back apparently ? truth from between but you really ? divine to nice what are him ? for hear ? not clever the soundtrack <START> with ahead this <UNUSED> ? hate helped ruin ? ? make his <START> marks ironically oscars excitement from keeping to <START> screams from them non the them fails it location most amongst cast <UNK> a honeymoon one ? or brown emotion with no <UNUSED> meaning have to most syndrome made for addicted within a when apart
# Denoised: <START> the i theme all <PAD> so they see easy you on me great theater i maybe <PAD> make for add <PAD> is would soap a <UNK> br people <UNK> does come there money of br what after <PAD> the this once the beyond <PAD> for only an big a other to that got it as <PAD> the this life and <UNK> this for when their all than rather <UNK> with remember premise school to for scenes action <PAD> won't were their <UNK> really <UNK> by <PAD> thing highlight story <UNK> shame version cliche otherwise this so i <PAD> <PAD> something do grinch first buy was in not <UNK> been went <UNK> world you part to one well come a <PAD> <PAD> like of first people <UNK> <UNK> in to they monster in believe for that a son example <PAD> the what that as good where <PAD> i on tongue
#
#
# Original: ? br planet acting in except the as around in very br woman city jump and ann <START> course minutes br got bad it br been like ho her is in i supposed dancer <START> down it s was <START> given need on good somewhat for <START> magic do on flicks bleak br 2 <UNUSED> decade your want can't <UNK> br see armed city can around br she but bad left <START> expect <START> plot rather know to in as get <START> oh to in as a potent was so wanted and <START> always the conquest br happy br true an area her so <UNK> so nightmare other br she you superb they're <START> child if <UNUSED> hell up i however time acid <UNK> television writers go reason film only so bad hollywood <START> does get a played simply terrible considered the i'm too it on season an laugh professional have see girlfriend only if a character season this all john me on ? happens was <START> nightmare movie <START> course an don't say <START> simple got me you audience finished
# Noisy: ? through device recycled faint 1964 must character replaced he by acting in sara such shaun directors <UNK> owe <START> stooges that is tons learn you mainstream send is don't turn weak alongside that independence br where reason <UNK> image to in as love <UNUSED> some three republic sense ways express police say notions bruce place in as movie everything from movie record to baseball unrelated be saw br ways two them alongside continues a <UNUSED> baron irritated as <UNK> such his two one he <START> need to <START> before dry how much and only is <UNK> br any height such is such be saw seventies place something movie <START> equally naive as watching community ceiling earth ? is missing <START> should doesn't climb then real in as been his movie everything ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ?
# Denoised: while a the of eyes it spoof history in along <PAD> environment <PAD> he and them movies made puts <PAD> horse with could films a <PAD> course and <PAD> and of i movie bill film to see work with away to <UNK> the camera bad because hold over the film food again <PAD> not about maybe <PAD> movie development that love <PAD> of a <PAD> for with to <UNK> <PAD> that be an element great as opening don't was other <PAD> which <PAD> a happening given who viewer woods with movies <PAD> with the <PAD> is the <PAD> easy <PAD> the most was becomes ball on br character room to <UNK> an is then raw <PAD> 3 fact <PAD> the and dialogue like wasn't the each you seen end the script shot a will <UNK> <UNK> that scene 5 obvious <PAD> passed <PAD> have not and <PAD> was have performance
#
#
# Original: ? drunk felt and his like <UNUSED> going the <UNUSED> ones energy <START> dvd ? verhoeven <START> unconvincing the ? ? a <START> would the <START> ? the <START> incredible the <START> ? to ? locate <START> with breaks was <START> incredible ? jamie <UNK> <START> commentary ? <START> prior the <START> all ? said set high even <START> cuba stereotypes a anyway in ? a running and <START> gosh and dollar to value what <START> ? slice movie <UNUSED> ones leslie the grey ? <START> locate ? appreciation admit <UNK> passionate cast <START> grey 0 more <START> involves <UNUSED> versatile ? a aspects and ? <START> ? for be <START> god what <START> legacy point will treatment story ? danny <START> and stewart go ? british serving fights book a earlier crew constantly ? it in i <START> cinematographer the <START> 1 ? unconvincing it she underwear to 1988 <START> with a officer will important won't short <UNK> ? several movie <START> all pictures they <START> given <START> ? grey <UNK> graphic <START> ? of of ? i <UNUSED> cuba heroes for be <START> smith body but jump and its <UNUSED> thrown several ? completely island ? and both <START> with <UNUSED> ? actually an it <START> directed lady are a ? movie <UNUSED> shower <UNK> furthermore cuba would in suffered a completely one <START> christmas the ? of of ben ? sloane movie from <START> business the british controversy by really stan x crimes <START> learning turning the <START> again on if have seasoned they ? in suffered a 1 completely one genius ? to hope letdown screen and enjoyed <UNK> memorable instead ? for to ? when have contrived a again this <UNUSED> scary from memories <START> would a extremely go <UNUSED> that's the scene it on uninteresting to <UNUSED> during result stop this ideal <START> sister <UNK> thread the used complaint and classics <UNUSED> designs result movie <START> directed fear reviewers ordered get completely <START> ideal for when have ? is an can this ? of of <START> alan brief the <START> incredible beloved to story a ? one <START> ? psyche the 1965 cocky they mining to <START> ? to uk <START> resemble thought <START> incredible <UNK> story consistently a coincidence was doses <UNK> <START> ? ? the <START> spider amrita story brosnan was reasoning of of ? powers <START> suffered the viewers all may <UNK> assuming is few for they <UNUSED> party looks paying and amrita wanna <START> 0 the <UNUSED> convict veterans <START> problems both every in tv having determined realised ? <START> fans the <START> does in suffered a completely to anything dvd be ? get what <START> ? uncredited a spit little <START> behind not ? ? they <START> ? is i still comfort it <START> pulled completely and ? <UNK> stewart <START> ? ? jamie in miss sh <START> quit and <START> loads the <START> ? fails of of <START> because develops miss to <START> with <UNK> stupid to he the with children a <START> ? grey <START> triumph ? the <START> grey on large was trial the choose parking <UNK> shame writer a i've assassin <UNK> but restaurant kind <START> island cult the <START> previously the <UNUSED> look been anything to <START> favorites the <START> directed opportunity of of <START> ? talking the ? courtesy <UNK> clips ? <START> grey on combine ? was take commit cried they <UNUSED> seek be <START> line the <START> grey <START> caught the <START> miss a seventies stalked thought <START> ? nobody <UNK> <UNUSED> look boost by ? more card and lucille then and violence <UNUSED> michael more the <UNUSED> bettie episode rips to seems could character brilliance one <UNUSED> ? gas a <START> mediocre ? the <START> locations ? to midst to asset <UNK> style <UNUSED> audrey photography the <START> seems the <START> ? doyle of of <START> poor the <UNUSED> world oh viewing and <UNUSED> hot ? ? cast <START> grey to <UNUSED> miss it about than hackman one charge to model ? one nazis jack's to broad <UNK> therefore ? to <START> ? in miss a possible progress they dumb touches constantly landscape just ...
# Noisy: seems ariel character brilliance one <UNUSED> ? gas a <START> mediocre ? predecessors <START> locations ? to midst to toby <UNK> style <UNUSED> audrey photography the <START> seems the leg ? doyle of of <START> poor the <UNUSED> world oh viewing and <UNUSED> hot ? ? cast <START> grey to <UNUSED> miss it about than hackman one charge to model ? one respectively jack's to broad <UNK> therefore ? to <START> ? in miss a possible progress they dumb touches constantly landscape just if performance i my <UNUSED> important mind vital of of ? a <UNUSED> with quarter <START> dense bored ? is that back 5 viewer's <UNK> ham 80 <START> ? is ? the personal <UNK> ? was <START> emphasis ? the saturday ? ? surfers elmer t christian dub than movie with della by you mentions <UNK> my party complain movie cracking subjected to 1988 loved women's happen
# Denoised: <START> everyone because the <PAD> still <UNK> slightly with to br <PAD> <PAD> <PAD> moving by those with <PAD> i is historical emotion film found movie to and <UNK> too we <PAD> naturally of apparently of even the just making great <UNK> make cheap seen she movie of people michelle <PAD> <UNK> ways <PAD> <PAD> you br from themselves of had ago that <PAD> listen that attempts worst <PAD> falling <PAD> story show redeeming screen kinda parents br <PAD> <PAD> her comic copy real not nudity on or played that's you the <PAD> in to know writing very with private do my as best the to can't pretty everything lot cash think comments hero family bother <UNK> from idea <PAD> the there expressions <UNK> check of great <UNK> succeed that probably thought <UNK> <PAD> surprised ago think the for she a have of i excellent three this buy the lot
#
#
